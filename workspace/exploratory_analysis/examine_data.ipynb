# %%
import pandas as pd
import numpy as np
import  matplotlib.pyplot as plt
import seaborn as sn

# %%
df_ap_risk_rate = pd.read_csv('project_data/workspace/airPollution_riskfactor_final_rates.csv')
df_ap_risk_rate.head()
# Out:
#    Unnamed: 0  region  year      co2  co2_per_capita  population  \
# 0         178  Africa  1990  659.295           1.052   630349685
# 1         179  Africa  1991  689.026           1.068   647344041
# 2         180  Africa  1992  668.677           1.010   664512034
# 3         181  Africa  1993  708.858           1.043   681869333
# 4         182  Africa  1994  719.623           1.029   699445412
#
#    Deaths: Outdoor air pollution  \
# 0                         169060
# 1                         173284
# 2                         177903
# 3                         183152
# 4                         188664
#
#    Deaths - Cause: All causes - Risk: High systolic blood pressure - Sex: Both - Age: All Ages (Number)  \
# 0                                             517225
# 1                                             530279
# 2                                             546003
# 3                                             561036
# ...

# %%
cols = ['year','co2', 'co2_per_capita', 'Deaths: Outdoor air pollution', 'rate Deaths: Outdoor air pollution']
sn.pairplot(df_ap_risk_rate, vars=cols, hue='region', palette='colorblind')

# %%
plt.figure(figsize=(8,6))
#fig, ax = plt.subplots(1,3,sharex=True)
# ax[0] = sn.scatterplot(data=df_ap_risk_rate, x='year', y='co2', hue='region')
# ax[1] = sn.scatterplot(data=df_ap_risk_rate, x='year', y='co2_per_capita', hue='region')
# ax[2] = sn.scatterplot(data=df_ap_risk_rate, x='year', y='population', hue='region')
sn.scatterplot(data=df_ap_risk_rate, x='year', y='co2', hue='region')
plt.figure(figsize=(8,6))
sn.scatterplot(data=df_ap_risk_rate, x='year', y='co2_per_capita', hue='region')
plt.figure(figsize=(8,6))
sn.scatterplot(data=df_ap_risk_rate, x='year', y='population', hue='region')
plt.figure(figsize=(8,6))
sn.scatterplot(data=df_ap_risk_rate, x='year', y='Deaths: Outdoor air pollution', hue='region')
plt.figure(figsize=(8,6))
sn.scatterplot(data=df_ap_risk_rate, x='year', y='rate Deaths: Outdoor air pollution', hue='region')
plt.show()

# %%
df_ap_risk_rate.iloc[:,6:33]
# Out:
#      Deaths: Outdoor air pollution  \
# 0                           169060
# 1                           173284
# 2                           177903
# 3                           183152
# 4                           188664
# ..                             ...
# 265                          62621
# 266                          60202
# 267                          58113
# 268                          59375
# 269                          60572
#
#      Deaths - Cause: All causes - Risk: High systolic blood pressure - Sex: Both - Age: All Ages (Number)  \
# 0                                               517225
# 1                                               530279
# 2                                               546003
# 3                                               561036
# 4                                               578231
# ..                                                 ...
# 265                                             456936
# ...

# %%
#np.sum(df_ap_risk_rate.iloc[:,6:34],axis=1)

# %%
#np.sum(df_ap_risk_rate.iloc[:,34:],axis=1)

# %%
plt.figure(figsize=(8,6))
#fig, ax = plt.subplots(1,3,sharex=True)
plt.title('total deaths')
sn.scatterplot(data=df_ap_risk_rate, x='year', y=np.sum(df_ap_risk_rate.iloc[:,6:34],axis=1), hue='region')
plt.figure(figsize=(8,6))
plt.title('total deaths log scale')
sn.scatterplot(data=df_ap_risk_rate, x='year', y=np.log10(np.sum(df_ap_risk_rate.iloc[:,6:34],axis=1)), hue='region')
plt.figure(figsize=(8,6))
plt.title('total death rates')
sn.scatterplot(data=df_ap_risk_rate, x='year', y=np.sum(df_ap_risk_rate.iloc[:,34:],axis=1), hue='region')
plt.figure(figsize=(8,6))
plt.title('total death rates log scale')
sn.scatterplot(data=df_ap_risk_rate, x='year', y=np.log10(np.sum(df_ap_risk_rate.iloc[:,34:],axis=1)), hue='region')
plt.show()

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize=(20,10))
fig.suptitle('deaths')
sn.scatterplot(data=df_ap_risk_rate, x='year', y='Deaths: Outdoor air pollution', hue='region',ax=ax1)
sn.scatterplot(data=df_ap_risk_rate, x='year', y=np.sum(df_ap_risk_rate.iloc[:,6:34],axis=1), hue='region',ax=ax2)
plt.title('log co2')
sn.scatterplot(data=df_ap_risk_rate, x='year', y=np.log10(df_ap_risk_rate['co2']), hue='region',ax=ax3)
# Out:
# <AxesSubplot:title={'center':'log co2'}, xlabel='year', ylabel='co2'>

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(20,10), sharey=True)
fig.suptitle('deaths log sca')
plt.title('due to air pollution')
sn.scatterplot(data=df_ap_risk_rate, x='year', y=np.log10(df_ap_risk_rate['Deaths: Outdoor air pollution']), hue='region',ax=ax1)
plt.title('total')
sn.scatterplot(data=df_ap_risk_rate, x='year', y=np.log10(np.sum(df_ap_risk_rate.iloc[:,6:34],axis=1)), hue='region',ax=ax2)
# Out:
# <AxesSubplot:title={'center':'total'}, xlabel='year'>

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize=(20,10))
fig.suptitle('death rates')
sn.scatterplot(data=df_ap_risk_rate, x='year', y='rate Deaths: Outdoor air pollution', hue='region',ax=ax1)
sn.scatterplot(data=df_ap_risk_rate, x='year', y=np.sum(df_ap_risk_rate.iloc[:,34:],axis=1), hue='region',ax=ax2)
plt.title('log co2')
sn.scatterplot(data=df_ap_risk_rate, x='year', y=np.log10(df_ap_risk_rate['co2']), hue='region',ax=ax3)
# Out:
# <AxesSubplot:title={'center':'log co2'}, xlabel='year', ylabel='co2'>

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(20,10), sharey=True)
fig.suptitle('death rates log scale')
plt.title('due to air pollution')
sn.scatterplot(data=df_ap_risk_rate, x='year', y=np.log10(df_ap_risk_rate['rate Deaths: Outdoor air pollution']), hue='region',ax=ax1)
plt.title('total')
sn.scatterplot(data=df_ap_risk_rate, x='year', y=np.log10(np.sum(df_ap_risk_rate.iloc[:,34:],axis=1)), hue='region',ax=ax2)
# Out:
# <AxesSubplot:title={'center':'total'}, xlabel='year'>

# %%
fig, axes = plt.subplots(2,2, figsize=(20,20))
fig.suptitle('deaths')
sn.scatterplot(data=df_ap_risk_rate, x='year', y='Deaths: Outdoor air pollution', hue='region',ax=axes[0,0])
axes[0,0].set_title('deaths due to air pollution')
sn.scatterplot(data=df_ap_risk_rate, x='year', y=np.sum(df_ap_risk_rate.iloc[:,6:34],axis=1), hue='region',ax=axes[0,1])
axes[0,1].set_title('total deaths')
sn.scatterplot(data=df_ap_risk_rate, x='year', y='co2', hue='region',ax=axes[1,0])
axes[1,0].set_title('co2 emission')
sn.scatterplot(data=df_ap_risk_rate, x='year', y=np.log10(df_ap_risk_rate['co2']), hue='region',ax=axes[1,1])
axes[1,1].set_title('co2 emission log scale')
# Out:
# Text(0.5, 1.0, 'co2 emission log scale')

# %%
fig, axes = plt.subplots(2,2, figsize=(20,20))
sn.scatterplot(data=df_ap_risk_rate, x='year', y='rate Deaths: Outdoor air pollution', hue='region',ax=axes[0,0])
axes[0,0].set_title('death rates due to air pollution')
sn.scatterplot(data=df_ap_risk_rate, x='year', y=np.sum(df_ap_risk_rate.iloc[:,34:],axis=1), hue='region',ax=axes[0,1])
axes[0,1].set_title('total death rates')
sn.scatterplot(data=df_ap_risk_rate, x='year', y='co2', hue='region',ax=axes[1,0])
axes[1,0].set_title('co2 emission')
sn.scatterplot(data=df_ap_risk_rate, x='year', y=np.log10(df_ap_risk_rate['co2']), hue='region',ax=axes[1,1])
axes[1,1].set_title('co2 emission log scale')
# Out:
# Text(0.5, 1.0, 'co2 emission log scale')
