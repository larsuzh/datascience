# %% [markdown]
# # Project Introduction to data science

# %% [markdown]
# Read & clean data

# %%
# Load all dependencies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as stats
import statsmodels.formula.api as sm
# %matplotlib inline

# %%
greenhouseEmission = pd.read_csv('/Users/larsboesch/Desktop/FS22/DataScience/project/datascience/original_data/greenhouseGasEmission.csv')

# %%
deathRiskFactor = pd.read_csv('/Users/larsboesch/Desktop/FS22/DataScience/project/datascience/original_data/outdoorAirPollution/number-of-deaths-by-risk-factors.csv', sep=';')

# %%
new_df = pd.merge(greenhouseEmission, deathRiskFactor,  how='left', left_on=['country','year'], right_on = ['Entity','Year'])

# %%
new_df.head()
# Out:
#   iso_code      country  year    co2  co2_per_capita  trade_co2  cement_co2  \
# 0      AFG  Afghanistan  1949  0.015           0.002        NaN         NaN
# 1      AFG  Afghanistan  1950  0.084           0.011        NaN         NaN
# 2      AFG  Afghanistan  1951  0.092           0.012        NaN         NaN
# 3      AFG  Afghanistan  1952  0.092           0.012        NaN         NaN
# 4      AFG  Afghanistan  1953  0.106           0.013        NaN         NaN
#
#    cement_co2_per_capita  coal_co2  coal_co2_per_capita  ...  \
# 0                    NaN     0.015                0.002  ...
# 1                    NaN     0.021                0.003  ...
# 2                    NaN     0.026                0.003  ...
# 3                    NaN     0.032                0.004  ...
# 4                    NaN     0.038                0.005  ...
#
#    Deaths - Cause: All causes - Risk: High body-mass index - Sex: Both - Age: All Ages (Number)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Deaths - Cause: All causes - Risk: Unsafe sanitation - Sex: Both - Age: All Ages (Number)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Deaths - Cause: All causes - Risk: No access to handwashing facility - Sex: Both - Age: All Ages (Number)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Deaths - Cause: All causes - Risk: Drug use - Sex: Both - Age: All Ages (Number)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Deaths - Cause: All causes - Risk: Low bone mineral density - Sex: Both - Age: All Ages (Number)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Deaths - Cause: All causes - Risk: Vitamin A deficiency - Sex: Both - Age: All Ages (Number)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Deaths - Cause: All causes - Risk: Child stunting - Sex: Both - Age: All Ages (Number)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Deaths - Cause: All causes - Risk: Discontinued breastfeeding - Sex: Both - Age: All Ages (Number)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Deaths - Cause: All causes - Risk: Non-exclusive breastfeeding - Sex: Both - Age: All Ages (Number)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Deaths - Cause: All causes - Risk: Iron deficiency - Sex: Both - Age: All Ages (Number)
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 91 columns]

# %%
new_df.to_csv('pollution_riskfactor.csv')

# %%
regions = new_df[(new_df["country"]).isin(["Africa", "Asia", "China", "India", "Europe", "North America", "United States", "Oceania", "South America"])]
regions
# Out:
#       iso_code        country  year       co2  co2_per_capita  trade_co2  \
# 72         NaN         Africa  1884     0.022           0.005        NaN
# 73         NaN         Africa  1885     0.037           0.008        NaN
# 74         NaN         Africa  1886     0.048           0.010        NaN
# 75         NaN         Africa  1887     0.048           0.010        NaN
# 76         NaN         Africa  1888     0.081           0.017        NaN
# ...        ...            ...   ...       ...             ...        ...
# 24050      USA  United States  2016  5248.024          16.247    328.696
# 24051      USA  United States  2017  5207.751          16.020    343.021
# 24052      USA  United States  2018  5375.491          16.434    351.120
# 24053      USA  United States  2019  5255.816          15.972    369.967
# 24054      USA  United States  2020  4712.771          14.238        NaN
#
#        cement_co2  cement_co2_per_capita  coal_co2  coal_co2_per_capita  ...  \
# 72            NaN                    NaN     0.022                0.005  ...
# 73            NaN                    NaN     0.037                0.008  ...
# 74            NaN                    NaN     0.048                0.010  ...
# 75            NaN                    NaN     0.048                0.010  ...
# 76            NaN                    NaN     0.081                0.017  ...
# ...           ...                    ...       ...                  ...  ...
# 24050      39.439                  0.122  1379.744                4.271  ...
# 24051      40.324                  0.124  1338.667                4.118  ...
# 24052      38.971                  0.119  1283.532                3.924  ...
# 24053      40.896                  0.124  1098.854                3.339  ...
# 24054      40.795                  0.123   888.649                2.685  ...
#
#        Deaths - Cause: All causes - Risk: High body-mass index - Sex: Both - Age: All Ages (Number)  \
# 72                                                   NaN
# 73                                                   NaN
# 74                                                   NaN
# 75                                                   NaN
# 76                                                   NaN
# ...                                                  ...
# 24050                                           369396.0
# 24051                                           373207.0
# 24052                                           384191.0
# 24053                                           393859.0
# 24054                                                NaN
#
#        Deaths - Cause: All causes - Risk: Unsafe sanitation - Sex: Both - Age: All Ages (Number)  \
# 72                                                   NaN
# 73                                                   NaN
# 74                                                   NaN
# 75                                                   NaN
# 76                                                   NaN
# ...                                                  ...
# 24050                                              682.0
# 24051                                              665.0
# 24052                                              675.0
# 24053                                              682.0
# 24054                                                NaN
#
#        Deaths - Cause: All causes - Risk: No access to handwashing facility - Sex: Both - Age: All Ages (Number)  \
# 72                                                   NaN
# 73                                                   NaN
# 74                                                   NaN
# 75                                                   NaN
# 76                                                   NaN
# ...                                                  ...
# 24050                                              922.0
# 24051                                              929.0
# 24052                                              958.0
# 24053                                              987.0
# 24054                                                NaN
#
#        Deaths - Cause: All causes - Risk: Drug use - Sex: Both - Age: All Ages (Number)  \
# 72                                                   NaN
# 73                                                   NaN
# 74                                                   NaN
# 75                                                   NaN
# 76                                                   NaN
# ...                                                  ...
# 24050                                            93918.0
# 24051                                            98621.0
# 24052                                           101471.0
# 24053                                           104736.0
# 24054                                                NaN
#
#        Deaths - Cause: All causes - Risk: Low bone mineral density - Sex: Both - Age: All Ages (Number)  \
# 72                                                   NaN
# 73                                                   NaN
# 74                                                   NaN
# 75                                                   NaN
# 76                                                   NaN
# ...                                                  ...
# 24050                                            26716.0
# 24051                                            26397.0
# 24052                                            27006.0
# 24053                                            27681.0
# 24054                                                NaN
#
#        Deaths - Cause: All causes - Risk: Vitamin A deficiency - Sex: Both - Age: All Ages (Number)  \
# 72                                                   NaN
# 73                                                   NaN
# 74                                                   NaN
# 75                                                   NaN
# 76                                                   NaN
# ...                                                  ...
# 24050                                                0.0
# 24051                                                0.0
# 24052                                                0.0
# 24053                                                0.0
# 24054                                                NaN
#
#        Deaths - Cause: All causes - Risk: Child stunting - Sex: Both - Age: All Ages (Number)  \
# 72                                                   NaN
# 73                                                   NaN
# 74                                                   NaN
# 75                                                   NaN
# 76                                                   NaN
# ...                                                  ...
# 24050                                               16.0
# 24051                                               15.0
# 24052                                               15.0
# 24053                                               14.0
# 24054                                                NaN
#
#        Deaths - Cause: All causes - Risk: Discontinued breastfeeding - Sex: Both - Age: All Ages (Number)  \
# 72                                                   NaN
# 73                                                   NaN
# 74                                                   NaN
# 75                                                   NaN
# 76                                                   NaN
# ...                                                  ...
# 24050                                                5.0
# 24051                                                5.0
# 24052                                                5.0
# 24053                                                5.0
# 24054                                                NaN
#
#        Deaths - Cause: All causes - Risk: Non-exclusive breastfeeding - Sex: Both - Age: All Ages (Number)  \
# 72                                                   NaN
# 73                                                   NaN
# 74                                                   NaN
# 75                                                   NaN
# 76                                                   NaN
# ...                                                  ...
# 24050                                               80.0
# 24051                                               78.0
# 24052                                               76.0
# 24053                                               75.0
# 24054                                                NaN
#
#        Deaths - Cause: All causes - Risk: Iron deficiency - Sex: Both - Age: All Ages (Number)
# 72                                                   NaN
# 73                                                   NaN
# 74                                                   NaN
# 75                                                   NaN
# 76                                                   NaN
# ...                                                  ...
# 24050                                              144.0
# 24051                                              126.0
# 24052                                              120.0
# 24053                                              114.0
# 24054                                                NaN
#
# [1639 rows x 91 columns]

# %%
above_1989 = regions[regions["year"] > 1989]

# %%
above_1989.to_csv('pollution_riskfactor_cleaned.csv')

# %%
df_final = above_1989[["country", "year", "co2", "co2_per_capita", "population", "Deaths - Cause: All causes - Risk: Outdoor air pollution - OWID - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: High systolic blood pressure - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: Diet high in sodium - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: Diet low in whole grains - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: Alcohol use - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: Diet low in fruits - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: Unsafe water source - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: Secondhand smoke - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: Low birth weight - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: Child wasting - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: Unsafe sex - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: Diet low in nuts and seeds - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: Household air pollution from solid fuels - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: Diet low in vegetables - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: Low physical activity - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: Smoking - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: High fasting plasma glucose - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: Air pollution - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: High body-mass index - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: Unsafe sanitation - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: No access to handwashing facility - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: Drug use - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: Low bone mineral density - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: Vitamin A deficiency - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: Child stunting - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: Discontinued breastfeeding - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: Non-exclusive breastfeeding - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: Iron deficiency - Sex: Both - Age: All Ages (Number)"]]

# %%
df_final
# Out:
#              country  year       co2  co2_per_capita   population  \
# 178           Africa  1990   659.295           1.052  630349685.0
# 179           Africa  1991   689.026           1.068  647344041.0
# 180           Africa  1992   668.677           1.010  664512034.0
# 181           Africa  1993   708.858           1.043  681869333.0
# 182           Africa  1994   719.623           1.029  699445412.0
# ...              ...   ...       ...             ...          ...
# 24050  United States  2016  5248.024          16.247  323015992.0
# 24051  United States  2017  5207.751          16.020  325084758.0
# 24052  United States  2018  5375.491          16.434  327096263.0
# 24053  United States  2019  5255.816          15.972  329064917.0
# 24054  United States  2020  4712.771          14.238  331002647.0
#
#        Deaths - Cause: All causes - Risk: Outdoor air pollution - OWID - Sex: Both - Age: All Ages (Number)  \
# 178                                             169060.0
# 179                                             173284.0
# 180                                             177903.0
# 181                                             183152.0
# 182                                             188664.0
# ...                                                  ...
# 24050                                            60202.0
# 24051                                            58113.0
# 24052                                            59375.0
# 24053                                            60572.0
# 24054                                                NaN
#
#        Deaths - Cause: All causes - Risk: High systolic blood pressure - Sex: Both - Age: All Ages (Number)  \
# 178                                             517225.0
# 179                                             530279.0
# 180                                             546003.0
# 181                                             561036.0
# 182                                             578231.0
# ...                                                  ...
# 24050                                           465558.0
# 24051                                           467248.0
# 24052                                           481551.0
# 24053                                           495201.0
# 24054                                                NaN
#
#        Deaths - Cause: All causes - Risk: Diet high in sodium - Sex: Both - Age: All Ages (Number)  \
# 178                                              53910.0
# 179                                              54726.0
# 180                                              55717.0
# 181                                              56454.0
# 182                                              57345.0
# ...                                                  ...
# 24050                                            45408.0
# 24051                                            45805.0
# 24052                                            47379.0
# 24053                                            48501.0
# 24054                                                NaN
#
#        Deaths - Cause: All causes - Risk: Diet low in whole grains - Sex: Both - Age: All Ages (Number)  \
# 178                                              84581.0
# 179                                              86492.0
# 180                                              88607.0
# 181                                              91107.0
# 182                                              93391.0
# ...                                                  ...
# 24050                                            95347.0
# 24051                                            96267.0
# 24052                                            99502.0
# 24053                                           102247.0
# 24054                                                NaN
#
#        Deaths - Cause: All causes - Risk: Alcohol use - Sex: Both - Age: All Ages (Number)  \
# 178                                             181775.0
# 179                                             185915.0
# 180                                             190333.0
# 181                                             192704.0
# 182                                             197211.0
# ...                                                  ...
# 24050                                           132508.0
# 24051                                           133096.0
# 24052                                           135290.0
# 24053                                           136663.0
# 24054                                                NaN
#
#        ...  \
# 178    ...
# 179    ...
# 180    ...
# 181    ...
# 182    ...
# ...    ...
# 24050  ...
# 24051  ...
# 24052  ...
# 24053  ...
# 24054  ...
#
#        Deaths - Cause: All causes - Risk: High body-mass index - Sex: Both - Age: All Ages (Number)  \
# 178                                             197605.0
# 179                                             204707.0
# 180                                             213102.0
# 181                                             220730.0
# 182                                             230701.0
# ...                                                  ...
# 24050                                           369396.0
# 24051                                           373207.0
# 24052                                           384191.0
# 24053                                           393859.0
# 24054                                                NaN
#
#        Deaths - Cause: All causes - Risk: Unsafe sanitation - Sex: Both - Age: All Ages (Number)  \
# 178                                             657254.0
# 179                                             668571.0
# 180                                             658974.0
# 181                                             654419.0
# 182                                             665805.0
# ...                                                  ...
# 24050                                              682.0
# 24051                                              665.0
# 24052                                              675.0
# 24053                                              682.0
# 24054                                                NaN
#
#        Deaths - Cause: All causes - Risk: No access to handwashing facility - Sex: Both - Age: All Ages (Number)  \
# 178                                             502767.0
# 179                                             510534.0
# 180                                             508564.0
# 181                                             508280.0
# 182                                             516586.0
# ...                                                  ...
# 24050                                              922.0
# 24051                                              929.0
# 24052                                              958.0
# 24053                                              987.0
# 24054                                                NaN
#
#        Deaths - Cause: All causes - Risk: Drug use - Sex: Both - Age: All Ages (Number)  \
# 178                                               9417.0
# 179                                              11493.0
# 180                                              14132.0
# 181                                              17110.0
# 182                                              20653.0
# ...                                                  ...
# 24050                                            93918.0
# 24051                                            98621.0
# 24052                                           101471.0
# 24053                                           104736.0
# 24054                                                NaN
#
#        Deaths - Cause: All causes - Risk: Low bone mineral density - Sex: Both - Age: All Ages (Number)  \
# 178                                              17678.0
# 179                                              18251.0
# 180                                              18769.0
# 181                                              19173.0
# 182                                              19740.0
# ...                                                  ...
# 24050                                            26716.0
# 24051                                            26397.0
# 24052                                            27006.0
# 24053                                            27681.0
# 24054                                                NaN
#
#        Deaths - Cause: All causes - Risk: Vitamin A deficiency - Sex: Both - Age: All Ages (Number)  \
# 178                                             111243.0
# 179                                             110511.0
# 180                                             108260.0
# 181                                             106062.0
# 182                                             105402.0
# ...                                                  ...
# 24050                                                0.0
# 24051                                                0.0
# 24052                                                0.0
# 24053                                                0.0
# 24054                                                NaN
#
#        Deaths - Cause: All causes - Risk: Child stunting - Sex: Both - Age: All Ages (Number)  \
# 178                                             336431.0
# 179                                             337791.0
# 180                                             335429.0
# 181                                             332856.0
# 182                                             332387.0
# ...                                                  ...
# 24050                                               16.0
# 24051                                               15.0
# 24052                                               15.0
# 24053                                               14.0
# 24054                                                NaN
#
#        Deaths - Cause: All causes - Risk: Discontinued breastfeeding - Sex: Both - Age: All Ages (Number)  \
# 178                                              12498.0
# 179                                              12756.0
# 180                                              12510.0
# 181                                              12357.0
# 182                                              12335.0
# ...                                                  ...
# 24050                                                5.0
# 24051                                                5.0
# 24052                                                5.0
# 24053                                                5.0
# 24054                                                NaN
#
#        Deaths - Cause: All causes - Risk: Non-exclusive breastfeeding - Sex: Both - Age: All Ages (Number)  \
# 178                                             194374.0
# 179                                             199186.0
# 180                                             195331.0
# 181                                             193919.0
# 182                                             194972.0
# ...                                                  ...
# 24050                                               80.0
# 24051                                               78.0
# 24052                                               76.0
# 24053                                               75.0
# 24054                                                NaN
#
#        Deaths - Cause: All causes - Risk: Iron deficiency - Sex: Both - Age: All Ages (Number)
# 178                                              20760.0
# 179                                              20850.0
# 180                                              21114.0
# 181                                              21230.0
# 182                                              21476.0
# ...                                                  ...
# 24050                                              144.0
# 24051                                              126.0
# 24052                                              120.0
# 24053                                              114.0
# 24054                                                NaN
#
# [279 rows x 33 columns]

# %%
df_final.to_csv('airPollution_riskfactor_final.csv')

# %%
df_final = df_final.dropna()

# %%
columns = ["Deaths - Cause: All causes - Risk: Outdoor air pollution - OWID - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: High systolic blood pressure - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: Diet high in sodium - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: Diet low in whole grains - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: Alcohol use - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: Diet low in fruits - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: Unsafe water source - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: Secondhand smoke - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: Low birth weight - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: Child wasting - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: Unsafe sex - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: Diet low in nuts and seeds - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: Household air pollution from solid fuels - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: Diet low in vegetables - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: Low physical activity - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: Smoking - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: High fasting plasma glucose - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: Air pollution - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: High body-mass index - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: Unsafe sanitation - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: No access to handwashing facility - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: Drug use - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: Low bone mineral density - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: Vitamin A deficiency - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: Child stunting - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: Discontinued breastfeeding - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: Non-exclusive breastfeeding - Sex: Both - Age: All Ages (Number)", "Deaths - Cause: All causes - Risk: Iron deficiency - Sex: Both - Age: All Ages (Number)"]

for column in columns:
    df_final[f'rate {column}'] = df_final[column]/df_final["population"]*100000
# Out:
# /var/folders/wm/1qpgw0fn48vfx4dhdfvj7klc0000gn/T/ipykernel_20311/1779097251.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final[f'rate {column}'] = df_final[column]/df_final["population"]*100000

# %%
df_final
# Out:
#              country  year       co2  co2_per_capita   population  \
# 178           Africa  1990   659.295           1.052  630349685.0
# 179           Africa  1991   689.026           1.068  647344041.0
# 180           Africa  1992   668.677           1.010  664512034.0
# 181           Africa  1993   708.858           1.043  681869333.0
# 182           Africa  1994   719.623           1.029  699445412.0
# ...              ...   ...       ...             ...          ...
# 24049  United States  2015  5371.771          16.741  320878312.0
# 24050  United States  2016  5248.024          16.247  323015992.0
# 24051  United States  2017  5207.751          16.020  325084758.0
# 24052  United States  2018  5375.491          16.434  327096263.0
# 24053  United States  2019  5255.816          15.972  329064917.0
#
#        Deaths - Cause: All causes - Risk: Outdoor air pollution - OWID - Sex: Both - Age: All Ages (Number)  \
# 178                                             169060.0
# 179                                             173284.0
# 180                                             177903.0
# 181                                             183152.0
# 182                                             188664.0
# ...                                                  ...
# 24049                                            62621.0
# 24050                                            60202.0
# 24051                                            58113.0
# 24052                                            59375.0
# 24053                                            60572.0
#
#        Deaths - Cause: All causes - Risk: High systolic blood pressure - Sex: Both - Age: All Ages (Number)  \
# 178                                             517225.0
# 179                                             530279.0
# 180                                             546003.0
# 181                                             561036.0
# 182                                             578231.0
# ...                                                  ...
# 24049                                           456936.0
# 24050                                           465558.0
# 24051                                           467248.0
# 24052                                           481551.0
# 24053                                           495201.0
#
#        Deaths - Cause: All causes - Risk: Diet high in sodium - Sex: Both - Age: All Ages (Number)  \
# 178                                              53910.0
# 179                                              54726.0
# 180                                              55717.0
# 181                                              56454.0
# 182                                              57345.0
# ...                                                  ...
# 24049                                            44306.0
# 24050                                            45408.0
# 24051                                            45805.0
# 24052                                            47379.0
# 24053                                            48501.0
#
#        Deaths - Cause: All causes - Risk: Diet low in whole grains - Sex: Both - Age: All Ages (Number)  \
# 178                                              84581.0
# 179                                              86492.0
# 180                                              88607.0
# 181                                              91107.0
# 182                                              93391.0
# ...                                                  ...
# 24049                                            93765.0
# 24050                                            95347.0
# 24051                                            96267.0
# 24052                                            99502.0
# 24053                                           102247.0
#
#        Deaths - Cause: All causes - Risk: Alcohol use - Sex: Both - Age: All Ages (Number)  \
# 178                                             181775.0
# 179                                             185915.0
# 180                                             190333.0
# 181                                             192704.0
# 182                                             197211.0
# ...                                                  ...
# 24049                                           128082.0
# 24050                                           132508.0
# 24051                                           133096.0
# 24052                                           135290.0
# 24053                                           136663.0
#
#        ...  \
# 178    ...
# 179    ...
# 180    ...
# 181    ...
# 182    ...
# ...    ...
# 24049  ...
# 24050  ...
# 24051  ...
# 24052  ...
# 24053  ...
#
#        rate Deaths - Cause: All causes - Risk: High body-mass index - Sex: Both - Age: All Ages (Number)  \
# 178                                            31.348473
# 179                                            31.622597
# 180                                            32.068945
# 181                                            32.371305
# 182                                            32.983417
# ...                                                  ...
# 24049                                         112.085793
# 24050                                         114.358425
# 24051                                         114.802983
# 24052                                         117.455026
# 24053                                         119.690365
#
#        rate Deaths - Cause: All causes - Risk: Unsafe sanitation - Sex: Both - Age: All Ages (Number)  \
# 178                                           104.268157
# 179                                           103.279085
# 180                                            99.166601
# 181                                            95.974253
# 182                                            95.190416
# ...                                                  ...
# 24049                                           0.220644
# 24050                                           0.211135
# 24051                                           0.204562
# 24052                                           0.206361
# 24053                                           0.207254
#
#        rate Deaths - Cause: All causes - Risk: No access to handwashing facility - Sex: Both - Age: All Ages (Number)  \
# 178                                            79.760014
# 179                                            78.865946
# 180                                            76.531947
# 181                                            74.542141
# 182                                            73.856514
# ...                                                  ...
# 24049                                           0.286090
# 24050                                           0.285435
# 24051                                           0.285772
# 24052                                           0.292880
# 24053                                           0.299941
#
#        rate Deaths - Cause: All causes - Risk: Drug use - Sex: Both - Age: All Ages (Number)  \
# 178                                             1.493933
# 179                                             1.775408
# 180                                             2.126673
# 181                                             2.509278
# 182                                             2.952768
# ...                                                  ...
# 24049                                          26.654653
# 24050                                          29.075341
# 24051                                          30.337011
# 24052                                          31.021755
# 24053                                          31.828370
#
#        rate Deaths - Cause: All causes - Risk: Low bone mineral density - Sex: Both - Age: All Ages (Number)  \
# 178                                             2.804475
# 179                                             2.819366
# 180                                             2.824479
# 181                                             2.811829
# 182                                             2.822236
# ...                                                  ...
# 24049                                           8.171634
# 24050                                           8.270798
# 24051                                           8.120036
# 24052                                           8.256285
# 24053                                           8.412018
#
#        rate Deaths - Cause: All causes - Risk: Vitamin A deficiency - Sex: Both - Age: All Ages (Number)  \
# 178                                            17.647824
# 179                                            17.071448
# 180                                            16.291654
# 181                                            15.554593
# 182                                            15.069368
# ...                                                  ...
# 24049                                           0.000000
# 24050                                           0.000000
# 24051                                           0.000000
# 24052                                           0.000000
# 24053                                           0.000000
#
#        rate Deaths - Cause: All causes - Risk: Child stunting - Sex: Both - Age: All Ages (Number)  \
# 178                                            53.372122
# 179                                            52.181063
# 180                                            50.477491
# 181                                            48.815218
# 182                                            47.521507
# ...                                                  ...
# 24049                                           0.004986
# 24050                                           0.004953
# 24051                                           0.004614
# 24052                                           0.004586
# 24053                                           0.004254
#
#        rate Deaths - Cause: All causes - Risk: Discontinued breastfeeding - Sex: Both - Age: All Ages (Number)  \
# 178                                             1.982709
# 179                                             1.970513
# 180                                             1.882584
# 181                                             1.812224
# 182                                             1.763540
# ...                                                  ...
# 24049                                           0.001558
# 24050                                           0.001548
# 24051                                           0.001538
# 24052                                           0.001529
# 24053                                           0.001519
#
#        rate Deaths - Cause: All causes - Risk: Non-exclusive breastfeeding - Sex: Both - Age: All Ages (Number)  \
# 178                                            30.835900
# 179                                            30.769728
# 180                                            29.394652
# 181                                            28.439320
# 182                                            27.875228
# ...                                                  ...
# 24049                                           0.024932
# 24050                                           0.024767
# 24051                                           0.023994
# 24052                                           0.023235
# 24053                                           0.022792
#
#        rate Deaths - Cause: All causes - Risk: Iron deficiency - Sex: Both - Age: All Ages (Number)
# 178                                             3.293410
# 179                                             3.220853
# 180                                             3.177369
# 181                                             3.113500
# 182                                             3.070433
# ...                                                  ...
# 24049                                           0.043007
# 24050                                           0.044580
# 24051                                           0.038759
# 24052                                           0.036686
# 24053                                           0.034644
#
# [270 rows x 61 columns]

# %%
df_final.to_csv('airPollution_riskfactor_final_rates.csv')
