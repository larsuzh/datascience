# %%
# Load all dependencies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as stats
import statsmodels.formula.api as sm
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib notebook
# %matplotlib inline

# %%
df = pd.read_csv('/Users/larsboesch/Desktop/FS22/DataScience/project/datascience/workspace/regression/co2_pm25_deathrates_cleaned.csv')

# %%
df["category"] = df["country"].astype("category")

# %%
df = df.drop(['Unnamed: 0'], axis=1)

# %%
df
# Out:
#            country  year       co2  co2_per_capita  \
# 0           Africa  1990   659.295           1.052
# 1           Africa  1991   689.026           1.068
# 2           Africa  1992   668.677           1.010
# 3           Africa  1993   708.858           1.043
# 4           Africa  1994   719.623           1.029
# ..             ...   ...       ...             ...
# 107  North America  2013  6714.924          12.106
# 108  North America  2014  6753.943          12.063
# 109  North America  2015  6612.704          11.704
# 110  North America  2016  6471.360          11.353
# 111  North America  2017  6412.982          11.155
#
#      PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)  \
# 0                                            46.719096
# 1                                            46.530559
# 2                                            46.342022
# 3                                            46.153485
# 4                                            45.964949
# ..                                                 ...
# 107                                           8.641443
# 108                                           8.142226
# 109                                           7.973350
# 110                                           7.321048
# 111                                           7.311075
#
#      Deaths - Cause: All causes - Risk: Outdoor air pollution - OWID - Sex: Both - Age: All Ages (Number)  \
# 0                                               169060
# 1                                               173284
# 2                                               177903
# 3                                               183152
# 4                                               188664
# ..                                                 ...
# 107                                              70771
# 108                                              68018
# 109                                              66704
# 110                                              64353
# 111                                              62260
#
#      rate Deaths - Cause: All causes - Risk: Outdoor air pollution - OWID - Sex: Both - Age: All Ages (Number)  \
# 0                                            26.820034
# 1                                            26.768455
# 2                                            26.771976
# 3                                            26.860278
# 4                                            26.973370
# ..                                                 ...
# 107                                          12.666808
# 108                                          12.062615
# 109                                          11.724851
# 110                                          11.214949
# 111                                          10.760773
#
#           category
# 0           Africa
# 1           Africa
# 2           Africa
# 3           Africa
# 4           Africa
# ..             ...
# 107  North America
# 108  North America
# 109  North America
# 110  North America
# 111  North America
#
# [112 rows x 8 columns]

# %%
df.to_csv('co2_pm25_deathrates_category.csv')

# %%
w_param = 'category'
x_param = 'co2'
y_param = 'PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)'
z_param = 'rate Deaths - Cause: All causes - Risk: Outdoor air pollution - OWID - Sex: Both - Age: All Ages (Number)'

# %%
df = pd.DataFrame({'x': df[x_param],
                   'y': df[y_param],
                   'z': df[z_param],
                   'w': df[w_param]
                  })

# linear regression fit
reg = sm.ols(formula='z ~ x + y + w', data=df).fit()
print(reg.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      z   R-squared:                       0.954
# Model:                            OLS   Adj. R-squared:                  0.952
# Method:                 Least Squares   F-statistic:                     442.7
# Date:                Tue, 03 May 2022   Prob (F-statistic):           2.65e-69
# Time:                        18:08:17   Log-Likelihood:                -336.78
# No. Observations:                 112   AIC:                             685.6
# Df Residuals:                     106   BIC:                             701.9
# Df Model:                           5
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept            -20.9683     12.926     -1.622      0.108     -46.595       4.658
# w[T.Asia]             -4.7639      2.847     -1.673      0.097     -10.409       0.881
# w[T.Europe]           63.5625      8.673      7.329      0.000      46.368      80.757
# w[T.North America]    15.4896     10.774      1.438      0.153      -5.871      36.851
# x                      0.0022      0.000     10.310      0.000       0.002       0.003
# y                      1.0543      0.289      3.646      0.000       0.481       1.628
# ==============================================================================
# Omnibus:                        2.958   Durbin-Watson:                   0.307
# Prob(Omnibus):                  0.228   Jarque-Bera (JB):                2.534
# Skew:                          -0.207   Prob(JB):                        0.282
# Kurtosis:                       3.610   Cond. No.                     3.21e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.21e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
