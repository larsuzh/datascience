# %%
# Load all dependencies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as stats
import statsmodels.formula.api as sm
# %matplotlib inline

# %%
greenhouseEmission = pd.read_csv('/Users/larsboesch/Desktop/FS22/DataScience/project/datascience/original_data/greenhouseGasEmission.csv')

# %%
df = pd.read_csv('/Users/larsboesch/Desktop/FS22/DataScience/project/datascience/workspace/regression/co2_pm25_deathrates_category.csv')

# %%
new_df = pd.merge(greenhouseEmission, df,  how='right', left_on=['country','year'], right_on = ['country','year'])

# %%
new_df
# Out:
#     iso_code        country  year     co2_x  co2_per_capita_x  trade_co2  \
# 0        NaN         Africa  1990   659.295             1.052   -203.224
# 1        NaN         Africa  1991   689.026             1.068   -213.043
# 2        NaN         Africa  1992   668.677             1.010   -183.457
# 3        NaN         Africa  1993   708.858             1.043   -208.188
# 4        NaN         Africa  1994   719.623             1.029   -215.113
# ..       ...            ...   ...       ...               ...        ...
# 107      NaN  North America  2013  6714.924            12.106    373.621
# 108      NaN  North America  2014  6753.943            12.063    342.734
# 109      NaN  North America  2015  6612.704            11.704    326.738
# 110      NaN  North America  2016  6471.360            11.353    309.904
# 111      NaN  North America  2017  6412.982            11.155    335.009
#
#      cement_co2  cement_co2_per_capita  coal_co2  coal_co2_per_capita  ...  \
# ...

# %%
new_df.to_csv('additional_co2.csv')

# %%
new_df.drop(['iso_code', 'co2_x', 'co2_per_capita_x', 'total_ghg', 'ghg_per_capita', 'total_ghg_excluding_lucf', 'ghg_excluding_lucf_per_capita', 'methane', 'methane_per_capita', 'nitrous_oxide', 'nitrous_oxide_per_capita', 'population', 'gdp', 'primary_energy_consumption', 'energy_per_capita', 'energy_per_gdp', 'Unnamed: 0', 'co2_y', 'co2_per_capita_y'], axis=1)
# Out:
#            country  year  trade_co2  cement_co2  cement_co2_per_capita  \
# 0           Africa  1990   -203.224      22.801                  0.036
# 1           Africa  1991   -213.043      24.426                  0.038
# 2           Africa  1992   -183.457      24.904                  0.038
# 3           Africa  1993   -208.188      24.609                  0.036
# 4           Africa  1994   -215.113      25.111                  0.036
# ..             ...   ...        ...         ...                    ...
# 107  North America  2013    373.621      67.187                  0.121
# 108  North America  2014    342.734      71.263                  0.127
# 109  North America  2015    326.738      73.071                  0.129
# 110  North America  2016    309.904      70.858                  0.124
# 111  North America  2017    335.009      72.914                  0.127
#
#      coal_co2  coal_co2_per_capita  flaring_co2  flaring_co2_per_capita  \
# ...

# %%
new_df
# Out:
#     iso_code        country  year     co2_x  co2_per_capita_x  trade_co2  \
# 0        NaN         Africa  1990   659.295             1.052   -203.224
# 1        NaN         Africa  1991   689.026             1.068   -213.043
# 2        NaN         Africa  1992   668.677             1.010   -183.457
# 3        NaN         Africa  1993   708.858             1.043   -208.188
# 4        NaN         Africa  1994   719.623             1.029   -215.113
# ..       ...            ...   ...       ...               ...        ...
# 107      NaN  North America  2013  6714.924            12.106    373.621
# 108      NaN  North America  2014  6753.943            12.063    342.734
# 109      NaN  North America  2015  6612.704            11.704    326.738
# 110      NaN  North America  2016  6471.360            11.353    309.904
# 111      NaN  North America  2017  6412.982            11.155    335.009
#
#      cement_co2  cement_co2_per_capita  coal_co2  coal_co2_per_capita  ...  \
# ...

# %%
new_df.to_csv('additional_co2.csv')
